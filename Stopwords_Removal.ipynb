# %% [markdown]
# <a href="https://colab.research.google.com/github/allexanderprastya/PROJECT-TA-JURNAL/blob/main/Stopwords_Removal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install swifter
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import swifter
import regex as re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize 
nltk.download('stopwords')
nltk.download('punkt')
stop_words = set(stopwords.words('indonesian'))

# import Sastrawi package
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv('/content/review_15k_clean.csv')

# %%
def stopwords_removal(text):
    tokens = word_tokenize(text)
    tokens = [w for w in tokens if not w in stop_words]
    return tokens

# %%
df['content'] = df['content'].swifter.apply(stopwords_removal)
df
# Out:
# Pandas Apply:   0%|          | 0/14737 [00:00<?, ?it/s]
#                                                  content sentiment
# 0      [bangke, gw, turun, nyangkut, kenok, langsung,...  positive
# 1          [manga, pa, pubg, loding, login, kuota, beli]  negative
# 2      [bag, nya, developer, perbaiki, ngeluh, karna,...  positive
# 3      [emang, berat, putaran, gak, kayak, ma, enak, ...   neutral
# 4      [game, bagus, sayang, ping, nya, klo, turun, a...  positive
# ...                                                  ...       ...
# 14732      [game, burik, hd, keburikannya, anzas, kelaz]  positive
# 14733                                            [lemot]   neutral
# 14734                                    [bagus, banget]  positive
# 14735  [game, serukerenhd, bug, pemakaian, memori, be...   neutral
# 14736                                     [gagal, login]  negative
#
# [14737 rows x 2 columns]

# %% [markdown]
# ###Stemming

# %%
def stemming_text(text): 
    factory = StemmerFactory()
    stemmer = factory.create_stemmer()
    text = [stemmer.stem(word) for word in text]
    return text

# %%
# %%time
df['content'] = df['content'].swifter.apply(stemming_text)
# Out:
# Pandas Apply:   0%|          | 0/14737 [00:00<?, ?it/s]
# CPU times: user 2h 48min 36s, sys: 47.7 s, total: 2h 49min 23s
# Wall time: 2h 50min 9s

# %%
def toSentence(text): # Convert list of words into sentence
    sentence = ' '.join(word for word in text)
    return sentence

# %%
df['content'] = df['content'].swifter.apply(toSentence)
# Out:
# Pandas Apply:   0%|          | 0/14737 [00:00<?, ?it/s]

# %%
df
# Out:
#                                                  content sentiment
# 0      bangke gw turun nyangkut kenok langsung tolong...  positive
# 1                  manga pa pubg loding login kuota beli  negative
# 2            bag nya developer baik ngeluh karna bag lag  positive
# 3         emang berat putar gak kayak ma enak main bagus   neutral
# 4      game bagus sayang ping nya klo turun an gempla...  positive
# ...                                                  ...       ...
# 14732                    game burik hd burik anzas kelaz  positive
# 14733                                                lot   neutral
# 14734                                       bagus banget  positive
# 14735  game serukerenhd bug pakai memori berat boros ...   neutral
# 14736                                        gagal login  negative
#
# [14737 rows x 2 columns]

# %%
df2.to_csv('review_15k_stopwords_stemming.csv',  encoding='utf8', index=None, header=True)

# %%
df = pd.read_csv('/content/review_15k_stopwords_stem.csv')
df.drop_duplicates(subset = 'content', inplace = True)

# %%
df.isna().sum()
# Out:
# content      1
# sentiment    0
# dtype: int64

# %%
df2 = df.dropna()
df2.isna().sum()
# Out:
# content      0
# sentiment    0
# dtype: int64

# %%
df2.sample(frac=1).reset_index()
# Out:
#       index                                            content sentiment
# 0       331                                       knapa update  positive
# 1      5401                          seru gamenya bug yo pabji  positive
# 2        25  segi grafik game bagus unggul terkadang frame ...  positive
# 3      4919                                    senja poinblank   neutral
# 4      6553                                       bnyk lag bug  positive
# ...     ...                                                ...       ...
# 8067  14173  tolong dep benerin bagi lobi karna lobi pas ko...   neutral
# 8068   3420  resource yg tdk henti downloadnya menganggu ko...   neutral
# 8069    852                 bug terjun pesawatselalu alami bug  negative
# 8070  11395  main game jelek coba hp jaring buka game pubg ...  negative
# 8071   2699                    gk ngerti gua main sumpah burik  negative
#
# [8072 rows x 3 columns]
