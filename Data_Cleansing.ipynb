# %% [markdown]
# <a href="https://colab.research.google.com/github/allexanderprastya/PROJECT-TA-JURNAL/blob/main/Data_Cleansing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install swifter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pandas as pd
import regex as re
import string
import swifter

# %%
df_clean = pd.read_csv("/content/review_15k_label.csv")

# %%
def cleansing(text):
    # Mengubah tipe data menjadi string
    text = str(text)
    #hapus non ASCII (hapus emoticon, chinese word, dll)
    text = text.encode("ascii", "replace").decode("ascii", " ")    
    # Mengubah setiap kata menjadi lowercase
    text =  text.lower()
    #menghapus number
    text = re.sub(r"\d+", " ", text) 
    # Menghapus Link Dengan Pattern http/https dan www
    text = re.sub(r"http\S+", " ", text)
    text = re.sub("(@\w+|#\w+)", " ", text)
    # Menghapus Tag HTML
    text = re.sub("<.*?>", " ", text)
    # Menghapus Tanda Baca Seperti Titik Dan Koma
    text = text.translate(str.maketrans(" ", " ", string.punctuation))
    # Menghapus Karakter Selain Huruf a-z dan A-Z
    text = re.sub("[^a-zA-Z]", " ", text)
    # Mengganti baris baru (enter) dengan spasi
    text = text.replace("\t"," ").replace("\n"," ").replace("\\"," ")
    # Menghapus Karakter Berulang (Contoh: Horeeee!!!! menjadi Hore!)
    text = re.sub(r"(\w)(\1{2,})", r"\1", text)
    text = re.sub(r"\b[a-zA-Z]\b"," ",text)
    text = text.strip()
    # Menghapus Spasi Yang Lebih Dari Satu
    return re.sub("\s+", " ",text)

# %%
df_clean["content"] = df_clean["content"].swifter.apply(cleansing)
df_clean
# Out:
# Pandas Apply:   0%|          | 0/15000 [00:00<?, ?it/s]
#                                                  content sentiment
# 0      bangke gw turun nyangkut kenok langsung tolong...  positive
# 1      manga pa pubg selalu loding ketika login padah...  negative
# 2      bag nya dong developer perbaiki semua ngeluh k...  positive
# 3      emang berat putaran kenapa gak seperti biasany...   neutral
# 4                                                         negative
# ...                                                  ...       ...
# 14995  game ini sangat burik dan sangat hd dengan keb...  positive
# 14996                                              lemot   neutral
# 14997                                       bagus banget  positive
# 14998  game serukerenhd tapi banyak bug pemakaian mem...   neutral
# 14999                                 sering gagal login  negative
#
# [15000 rows x 2 columns]

# %%
df_clean.to_csv("review_15_clean.csv",  encoding="utf8", index=None, header=True)

# %%
df = pd.read_csv("/content/review_15_clean.csv")
df['content'].duplicated().sum()
# Out:
# 6673

# %%
df.drop_duplicates(subset="content", inplace=True)

# %%
len(df)
# Out:
# 8327

# %%
df2 = df.dropna()
df2.isna().sum()
# Out:
# content      0
# sentiment    0
# dtype: int64

# %%
df2.reset_index(inplace=True)

# %%
df2
# Out:
#       index                                            content sentiment
# 0         0  bangke gw turun nyangkut kenok langsung tolong...  positive
# 1         1  manga pa pubg selalu loding ketika login padah...  negative
# 2         2  bag nya dong developer perbaiki semua ngeluh k...  positive
# 3         3  emang berat putaran kenapa gak seperti biasany...   neutral
# 4         5  game ini sudah bagus tapi sayang ping nya sela...  positive
# ...     ...                                                ...       ...
# 8321  14961  aku sangat senang dengan pubg yg sekarang wala...  positive
# 8322  14965  the developer of this game is very stingy with...  negative
# 8323  14983   ya sy sngat sk dgn game inieror lambat star game   neutral
# 8324  14989                                         frame drop   neutral
# 8325  14991  jaringan di loby suka ngelag padahal sebelum u...   neutral
#
# [8326 rows x 3 columns]

# %%
df2.to_csv("review_15k_clean.csv",  encoding="utf8", index=None, header=True)
