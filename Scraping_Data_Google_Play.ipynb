# %% [markdown]
# <a href="https://colab.research.google.com/github/allexanderprastya/PROJECT-TA-JURNAL/blob/main/Scraping_Data_Google_Play.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Scraping data 1

# %%
pip install google_play_scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.2-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.2

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.tencent.ig',
    lang = 'id',
    country = 'id',
    sort = Sort.NEWEST,
    count = 2500,
    filter_score_with = 1
)

# %%
import pandas as pd

# %%
df = pd.DataFrame(result)

# %%
df.shape
# Out:
# (2500, 10)

# %%
df.head()
# Out:
#                                reviewId           userName  \
# 0  0411cdc3-14bd-411e-b4a8-f1f94240c89c    Saputra Saputra
# 1  846b7e2a-1760-415b-ae13-988fe4376b30  Nurfajar Awaludin
# 2  2ead5c87-0f37-4a94-bea0-3fde3481b291   Partogi Sihotang
# 3  d57e3b15-8727-48b5-b246-886031e03614     Surya Imansyah
# 4  b0d7b2c3-5700-4cfc-89c9-3cc03f29d2bd            pubg kr
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AItbvm...
# 1  https://play-lh.googleusercontent.com/a-/AFdZu...
# 2  https://play-lh.googleusercontent.com/a-/AFdZu...
# 3  https://play-lh.googleusercontent.com/a-/AFdZu...
# 4  https://play-lh.googleusercontent.com/a/AItbvm...
#
#                                              content  score  thumbsUpCount  \
# 0                                     Level 30 vs 70      1              0
# 1  Tencent ini gimana kok aku buka peti dapetnya ...      1              0
# 2  Yang saya malas naik motor nanti tembus ke tan...      1              0
# 3       Bagus game nya grafik nya ga burik kaya efef      1              0
# 4                                        game kontol      1              0
#
#   reviewCreatedVersion                  at  \
# 0                2.1.0 2022-09-13 08:34:58
# 1                1.3.0 2022-09-13 08:08:39
# 2                2.1.0 2022-09-13 07:31:08
# 3                 None 2022-09-13 07:29:06
# 4                 None 2022-09-13 07:25:01
#
#                                         replyContent           repliedAt
# 0                                               None                 NaT
# 1  Halo, kami mohon maaf atas ketidaknyamanan ini... 2021-03-11 02:09:12
# 2                                               None                 NaT
# 3  Halo Surya, kami prihatin mendengar Anda menga... 2022-09-13 07:17:27
# 4  Hello, thanks for the feedback! If you'd like ... 2022-09-13 10:15:21

# %%
df.to_csv('review_score_1.csv', index=None, header=True, encoding ="utf-8")

# %% [markdown]
# ###Scraping data 2

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.tencent.ig',
    lang = 'id',
    country = 'id',
    sort = Sort.NEWEST,
    count = 2500,
    filter_score_with = 2
)

# %%
df_1 = pd.DataFrame(result)

# %%
df_1.shape
# Out:
# (2500, 10)

# %%
df_1.head()
# Out:
#                                reviewId      userName  \
# 0  8fb828f4-9e92-45d6-898f-0cd9c8d906cd       Kak Ace
# 1  cb9bd817-b844-42ed-acf5-03cf95c79667  jumardi ardi
# 2  eea74a6f-a0c5-453b-8151-fccaef679385     SAINTS ET
# 3  4d88a2b2-9222-4f34-a05e-fde73d454d2c  Rain Angkasa
# 4  f1f16ee1-b2e4-48c0-b4e0-92c8ca3c9276  Ajigg Sultan
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AFdZu...
# 1  https://play-lh.googleusercontent.com/a-/AFdZu...
# 2  https://play-lh.googleusercontent.com/a-/AFdZu...
# 3  https://play-lh.googleusercontent.com/a/AItbvm...
# 4  https://play-lh.googleusercontent.com/a-/AFdZu...
#
#                                              content  score  thumbsUpCount  \
# 0                                          Coba dulu      2              0
# 1  Kok metro royale gak ada,saya suka main di sit...      2              0
# 2        bug, cheat dan jaringan masih bermasalah...      2              1
# 3          Permisi bole bilang mana metro royale nya      2              0
# 4  Setelah pubg bukan sama tencen banyak keanehan...      2              0
#
#   reviewCreatedVersion                  at  \
# 0                 None 2022-09-13 08:07:29
# 1                2.1.0 2022-09-13 07:34:03
# 2                2.1.0 2022-09-13 05:55:43
# 3                 None 2022-09-13 05:41:48
# 4                 None 2022-09-13 05:32:21
#
#                                         replyContent           repliedAt
# 0  Halo Kak Ace, mohon maaf jika PUBG Mobile tida... 2021-02-05 15:28:49
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4                                               None                 NaT

# %%
df_1.to_csv('review_score_2.csv', index=None, header=True, encoding ="utf-8")

# %% [markdown]
# ###Scraping data 3

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.tencent.ig',
    lang = 'id',
    country = 'id',
    sort = Sort.NEWEST,
    count = 5000,
    filter_score_with = 3
)

# %%
df_2 = pd.DataFrame(result)

# %%
df_2.shape
# Out:
# (5000, 10)

# %%
df_2.head()
# Out:
#                                reviewId            userName  \
# 0  31e61ce4-0741-4d7c-b041-3f31b962fa6f           Reza Reza
# 1  a84daa13-80e1-4bb8-834d-3804e537d950             Nail 22
# 2  2ceada49-ef40-4eb1-bcd4-cc9a149cac22               iNoxx
# 3  e3960397-fa5d-4eaa-b327-36886d260dde  RAIHAN ALE SAPUTRA
# 4  4258d80b-7a7e-4ae5-ba52-c7a05ebce809           Roni udis
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AItbvm...
# 1  https://play-lh.googleusercontent.com/a-/AFdZu...
# 2  https://play-lh.googleusercontent.com/a-/AFdZu...
# 3  https://play-lh.googleusercontent.com/a-/AFdZu...
# 4  https://play-lh.googleusercontent.com/a-/AFdZu...
#
#                                              content  score  thumbsUpCount  \
# 0          kok gk bisa login padahal jaringan gk leg      3              0
# 1  Ini game makin lama makin lama Cheatersnya ban...      3              0
# 2          kenapa sekarang pubg tidak senyaman dulu?      3              0
# 3                             Biar orang menilai nya      3              0
# 4  Masih banyak pengguna aplikasi mod. Atau body ...      3              2
#
#   reviewCreatedVersion                  at  \
# 0                2.1.0 2022-09-13 08:48:27
# 1                 None 2022-09-13 07:09:43
# 2                1.6.0 2022-09-13 06:17:16
# 3                 None 2022-09-13 06:06:57
# 4                2.1.0 2022-09-13 04:16:41
#
#                                         replyContent           repliedAt
# 0                                               None                 NaT
# 1                                               None                 NaT
# 2                                               None                 NaT
# 3                                               None                 NaT
# 4  Hai Roni udis, kami akan terus memberantas per... 2022-08-28 05:07:14

# %%
df_2.to_csv('review_score_3.csv', index=None, header=True, encoding ="utf-8")

# %% [markdown]
# ###Scraping data 4

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.tencent.ig',
    lang = 'id',
    country = 'id',
    sort = Sort.NEWEST,
    count = 2500,
    filter_score_with = 4
)

# %%
df_3 = pd.DataFrame(result)

# %%
df_3.shape
# Out:
# (2500, 10)

# %%
df_3.head()
# Out:
#                                reviewId                 userName  \
# 0  1d76208c-02b9-402a-82e0-118fa9b2e4a8           Faaris Annaafi
# 1  d4edac3d-0a74-4cd8-bd63-4be83745e271  I Putu Nugraha Diatmika
# 2  4a880a9f-108a-4ee8-a984-2b70b31f148d            cantika laiqa
# 3  3c881b75-c304-4d24-9381-c26adaa7e5b5                     Zann
# 4  16d8ac09-538e-4f3d-bfd1-7e3bd67d7ea7               Habib Zaky
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AFdZu...
# 1  https://play-lh.googleusercontent.com/a-/AFdZu...
# 2  https://play-lh.googleusercontent.com/a-/AFdZu...
# 3  https://play-lh.googleusercontent.com/a-/AFdZu...
# 4  https://play-lh.googleusercontent.com/a-/AFdZu...
#
#                                              content  score  thumbsUpCount  \
# 0  Kenapa saat matching cari room buat miramar ja...      4              0
# 1                         Bug map gak bisa milih map      4              0
# 2  Gamenya udah seru banget tapi ada yg kurang di...      4              0
# 3                                   minimal pubg dek      4              0
# 4  Saya kok tidak bisa log in kmbali pake akun go...      4              0
#
#   reviewCreatedVersion                  at  \
# 0                2.1.0 2022-09-13 08:59:26
# 1                2.1.0 2022-09-13 03:57:19
# 2                 None 2022-09-12 20:50:46
# 3                 None 2022-09-12 19:59:36
# 4                 None 2022-09-12 19:59:01
#
#                                         replyContent           repliedAt
# 0  Halo Faaris Annaafi, kami menyesal mendengar A... 2022-09-12 12:13:19
# 1  Halo Nugraha , kami mohon maaf atas ketidaknya... 2022-09-14 07:09:40
# 2  Halo laiqa, kami benar-benar menghargai umpan ... 2022-09-13 05:15:37
# 3  Merhabalar, oyunumuzdan memnun olduğunu duyduğ... 2022-09-13 11:23:01
# 4  Halo Habib , kami menyesal mendengar Anda meng... 2022-09-13 06:20:14

# %%
df_3.to_csv('review_score_4.csv', index=None, header=True, encoding ="utf-8")

# %% [markdown]
# ###Scraping data 5

# %%
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.tencent.ig',
    lang = 'id',
    country = 'id',
    sort = Sort.NEWEST,
    count = 2500,
    filter_score_with = 5
)

# %%
df_4 = pd.DataFrame(result)

# %%
df_4.shape
# Out:
# (2500, 10)

# %%
df_4.head()
# Out:
#                                reviewId          userName  \
# 0  6029555f-9058-47a6-8e0c-beec24fe2168  Ahmad Apriliyano
# 1  b14a8071-9661-41f2-b962-18a7be5bf5ed   Hordova Rayauda
# 2  89375924-1ba9-48f4-9c0c-05e1422c9fb4   Muhammad Muslih
# 3  aec781e0-6c01-483e-a909-21a6461b3971       BANA GAMING
# 4  1fef0e35-2b6b-4a1b-bbee-80a5249ae0d0    Rahmat_ Art_77
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/AItbvm...
# 1  https://play-lh.googleusercontent.com/a/AItbvm...
# 2  https://play-lh.googleusercontent.com/a-/AFdZu...
# 3  https://play-lh.googleusercontent.com/a-/AFdZu...
# 4  https://play-lh.googleusercontent.com/a-/AFdZu...
#
#                       content  score  thumbsUpCount reviewCreatedVersion  \
# 0                     Pokemon      5              0                 None
# 1  Sangat bagus dan saya suka      5              0                 None
# 2              aplikasi bagus      5              0                 None
# 3                Bagus banget      5              0                 None
# 4                       Bagus      5              0                 None
#
#                    at                                       replyContent  \
# 0 2022-09-13 08:50:35                                               None
# 1 2022-09-13 08:42:15  Halo Hordova , kami senang mendengar bahwa And...
# 2 2022-09-13 08:29:53  Hai Muslih, terima kasih atas kata-kata baik A...
# 3 2022-09-13 08:21:30  Hai, kami selalu mencoba memastikan game ini t...
# 4 2022-09-13 08:10:15  Halo Rahmat_ Art_77, kami ingin mengucapkan te...
#
#             repliedAt
# 0                 NaT
# 1 2022-09-14 06:30:59
# 2 2022-09-14 06:30:47
# 3 2020-10-29 02:45:03
# 4 2022-09-14 06:30:12

# %%
df_4.to_csv('review_score_5.csv', index=None, header=True, encoding ="utf-8")

# %% [markdown]
# #Merge Excel

# %%
from glob import glob

# %%
df_5 = sorted(glob('/content/data/review_score*.csv'))
df_5
# Out:
# ['/content/data/review_score_1.csv',
#  '/content/data/review_score_2.csv',
#  '/content/data/review_score_3.csv',
#  '/content/data/review_score_4.csv',
#  '/content/data/review_score_5.csv']

# %%
# %%time 
df_6 = pd.concat((pd.read_csv(file).assign(filename = file) for file in df_5), ignore_index = True)
# Out:
# CPU times: user 177 ms, sys: 32.1 ms, total: 209 ms
# Wall time: 314 ms

# %%
df_7 = df_6.sample(frac=1, replace=True, random_state=1).reset_index()

# %%
df_7
# Out:
#        index                              reviewId                userName  \
# 0      13349  5e8751e9-4a6c-4e64-994d-31b7a2ea5971              AGG GARAGE
# 1        235  653656ce-7086-4fd3-a481-619a658b2a7c              Herul Idoy
# 2      12172  5c6746b5-19b6-46d1-8c0a-3bbfd6cc11b9           Rayyan Habibi
# 3       5192  aff528b9-22d8-4eca-a840-f606fe23db16               As Miyati
# 4        905  b2c5337a-5c2e-4892-aad2-d66d3aa462ab                  Danial
# ...      ...                                   ...                     ...
# 14995  12990  38baf109-523f-4026-b1c8-82a3bb9eaa52              saha maneh
# 14996   6686  a9d339f4-ca39-4b10-ab89-5af8bdf44f27  Muhammad fajar Anshari
# 14997  12503  aec781e0-6c01-483e-a909-21a6461b3971             BANA GAMING
# 14998   7399  623ea637-d841-443b-89b0-675537c6b90d           Totoi Tuwanto
# 14999    441  05eb0864-926b-4339-a7ba-15cf896e1a6f                Lia Mbul
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/a-/AFdZu...
# 1      https://play-lh.googleusercontent.com/a/AItbvm...
# 2      https://play-lh.googleusercontent.com/a-/AFdZu...
# 3      https://play-lh.googleusercontent.com/a-/AFdZu...
# 4      https://play-lh.googleusercontent.com/a-/AFdZu...
# ...                                                  ...
# 14995  https://play-lh.googleusercontent.com/a-/AFdZu...
# 14996  https://play-lh.googleusercontent.com/a-/AFdZu...
# 14997  https://play-lh.googleusercontent.com/a-/AFdZu...
# 14998  https://play-lh.googleusercontent.com/a-/AFdZu...
# 14999  https://play-lh.googleusercontent.com/a/AItbvm...
#
#                                                  content  score  \
# 0      Bangke gw turun nyangkut kenok langsung tolong...      5
# 1      Manga pa pubg selalu loding ketika login padah...      1
# 2      Bag nya dong developer perbaiki semua ngeluh k...      4
# 3      Emang berat putaran kenapa gak seperti biasany...      3
# 4                                                   P :v      1
# ...                                                  ...    ...
# 14995  Game ini sangat burik dan sangat hd dengan keb...      5
# 14996                                              Lemot      3
# 14997                                       Bagus banget      5
# 14998  Game seru,keren,hd ;tapi banyak bug, pemakaian...      3
# 14999                                 Sering gagal login      1
#
#        thumbsUpCount reviewCreatedVersion                   at  \
# 0                  0                  NaN  2022-09-03 15:50:09
# 1                  0                2.1.0  2022-09-10 00:24:20
# 2                  0                  NaN  2022-06-14 03:26:20
# 3                  0                  NaN  2022-08-30 22:01:07
# 4                  0                  NaN  2022-08-29 15:17:29
# ...              ...                  ...                  ...
# 14995              0                  NaN  2022-09-08 09:34:05
# 14996              0                  NaN  2022-07-10 05:37:14
# 14997              0                  NaN  2022-09-13 08:21:30
# 14998              0                  NaN  2022-06-04 04:00:32
# 14999              0                2.1.0  2022-09-06 11:29:06
#
#                                             replyContent            repliedAt  \
# 0      Halo AGG GARAGE, kami menyesal mendengar Anda ...  2022-09-04 07:18:25
# 1      Halo Herul , kami menyesal mendengar Anda meng...  2022-09-10 08:56:28
# 2      Halo Rayyan, kami mohon maaf atas ketidaknyama...  2022-06-15 18:58:12
# 3      Halo Miyati, kami mohon maaf atas ketidaknyama...  2022-08-31 08:01:41
# 4      Halo Danial, kami memerlukan lebih banyak info...  2022-08-31 03:44:15
# ...                                                  ...                  ...
# 14995  Halo saha , kami memerlukan lebih banyak infor...  2022-09-09 06:22:37
# 14996  Halo fajar, kami memerlukan lebih banyak infor...  2022-08-23 12:15:59
# 14997  Hai, kami selalu mencoba memastikan game ini t...  2020-10-29 02:45:03
# 14998  Hai Totoi Tuwanto, kami menyesal mendengar And...  2022-06-05 07:05:53
# 14999  Halo Lia, kami mohon maaf mendengar bahwa Anda...  2022-09-07 18:37:44
#
#                                filename
# 0      /content/data/review_score_5.csv
# 1      /content/data/review_score_1.csv
# 2      /content/data/review_score_4.csv
# 3      /content/data/review_score_3.csv
# 4      /content/data/review_score_1.csv
# ...                                 ...
# 14995  /content/data/review_score_5.csv
# 14996  /content/data/review_score_3.csv
# 14997  /content/data/review_score_5.csv
# 14998  /content/data/review_score_3.csv
# 14999  /content/data/review_score_1.csv
#
# [15000 rows x 12 columns]

# %%
df_7.to_csv('review_15k.csv', index=None, header=True, encoding ="utf-8")

# %%
from google.colab import files
files.download('/content/review_15k.csv')
