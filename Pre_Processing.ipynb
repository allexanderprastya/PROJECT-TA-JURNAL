# %% [markdown]
# <a href="https://colab.research.google.com/github/allexanderprastya/ANALYSIS-SENTIMENT-BERT/blob/main/Pre_Processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
import string

# %% [markdown]
# PRE-PROCESSING

# %%
df2 = pd.read_csv('/content/review_label.csv')

# %%
# check for NaN values and remove them (optional)
df2 = df3.dropna()

# %%
#Changing Text to Lower Case in Pandas
df2['content'] = df2['content'].str.lower()
df2
# Out:
#                                                  content  sentiment
# 0      saya suka game ini,tapi sayang banyak sekali c...          2
# 1      ping nya selalu ga stabil tiba2 bisa sampe 600...          0
# 2      mantap game terbaik.. up date nyaaa seharian p...          1
# 3                                       dowload nya lama          0
# 4                                            gem burikan          1
# ...                                                  ...        ...
# 29995    kebanyakan update handphone pacar aku gk kuat 😤          1
# 29996  tolong pihal dev untuk benerin bug setelah upd...          1
# 29997                                               pubg          2
# 29998  di lobby suka lag sendiri padahal udah ganti j...          1
# 29999                                     banyak cheater          0
#
# [30000 rows x 2 columns]

# %%
def cleaning_data(text):
    #hapus non ASCII (hapus emoticon, chinese word, dll)
    text = text.encode('ascii', 'replace').decode('ascii')
    #Remove punctuation
    text = text.translate(str.maketrans('','',string.punctuation))
    #hapus angka
    text = re.sub(r'\d+', ' ', text)
    #Remove multiple whitespace
    text = re.sub('\s+', ' ',text)
    # remove single char
    return re.sub(r'\b[a-zA-Z]\b', '', text)
    
df2['content'] = df2['content'].apply(cleaning_data)
df2
# Out:
#                                                  content  sentiment
# 0      saya suka game initapi sayang banyak sekali ch...          2
# 1      ping nya selalu ga stabil tiba bisa sampe lah ...          0
# 2      mantap game terbaik up date nyaaa seharian pen...          1
# 3                                       dowload nya lama          0
# 4                                            gem burikan          1
# ...                                                  ...        ...
# 29995     kebanyakan update handphone pacar aku gk kuat           1
# 29996  tolong pihal dev untuk benerin bug setelah upd...          1
# 29997                                               pubg          2
# 29998  di lobby suka lag sendiri padahal udah ganti j...          1
# 29999                                     banyak cheater          0
#
# [30000 rows x 2 columns]

# %%
# check for NaN values and remove them (optional)
df2.dropna(inplace=True)

# %%
from google.colab import files
df2.to_csv('review_cleaning_data.csv', index=None, header=True)
files.download('/content/review_cleaning_data.csv')

# %% [markdown]
# #Tokenization

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize,sent_tokenize
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
df3 = pd.read_csv('/content/review_cleaning_data.csv')
df3
# Out:
#                                                  content  sentiment
# 0      saya suka game initapi sayang banyak sekali ch...          2
# 1      ping nya selalu ga stabil tiba bisa sampe lah ...          0
# 2      mantap game terbaik up date nyaaa seharian pen...          1
# 3                                       dowload nya lama          0
# 4                                            gem burikan          1
# ...                                                  ...        ...
# 29995     kebanyakan update handphone pacar aku gk kuat           1
# 29996  tolong pihal dev untuk benerin bug setelah upd...          1
# 29997                                               pubg          2
# 29998  di lobby suka lag sendiri padahal udah ganti j...          1
# 29999                                     banyak cheater          0
#
# [30000 rows x 2 columns]

# %%
# check for NaN values and remove them (optional)
df_2["content"].dropna(inplace=True)

# convert the column to string
df_2['content'] = df_2['content'].astype(str)

# %%
def word_tokenize_wrapper(text):
    return word_tokenize(text)

df_2['comment'] = df_2['comment'].apply(word_tokenize_wrapper)

# %%
df_2.head()
# Out:
#                                              comment  sentiment
# 0  [game, ini, bagustapi, lebih, bagus, game, gim...          2
# 1                                        [gem, bgus]          2
# 2  [akun, pubg, ku, kena, heckergimna, sih, cara,...          1
# 3  [plis, jangan, mahal, mahal, men, ganti, jadi,...          2
# 4                             [mntep, dah, pokoknya]          2

# %% [markdown]
# #Stopwords

# %%
def stopward_removal(text):
    filtering =  set(stopwords.words('indonesian','english'))
    x = []
    data = []
    def myFunc(x):
        if x in filtering:
            return False
        else:
            return True
    fit = filter(myFunc, text)
    for x in fit:
        data.append(x)
    return data
    
df_2['comment'] = df_2['comment'].apply(stopward_removal)
df_2.head(10)
# Out:
#                                              comment  sentiment
# 0  [game, bagustapi, bagus, game, gimbot, karya, ...          2
# 1                                        [gem, bgus]          2
# 2  [akun, pubg, ku, kena, heckergimna, sih, menga...          1
# 3  [plis, mahal, mahal, men, ganti, mb, men, maaf...          2
# 4                             [mntep, dah, pokoknya]          2
# 5  [kah, kedepannya, pubg, settingan, fps, snapdr...          2
# 6                                       [game, seru]          2
# 7                                    [hp, mendukung]          2
# 8  [gamenya, bagus, tp, knp, ketemu, musuh, patah...          2
# 9       [up, date, mulu, dipasangin, cheat, ghoblok]          0

# %%
df_2.to_csv('reviews_clean_2.csv', index=False, header=True)

# %%
df_3 = pd.read_csv('/content/reviews_clean_2.csv')

# %%
def string_tolist(text):
    return text[1:-1].split(",")

df_3['comment'] = df_3['comment'].apply(string_tolist)
df_3
# Out:
#                                                  comment  sentiment
# 0      ['game',  'bagustapi',  'bagus',  'game',  'gi...          2
# 1                                       ['gem',  'bgus']          2
# 2      ['akun',  'pubg',  'ku',  'kena',  'heckergimn...          1
# 3      ['plis',  'mahal',  'mahal',  'men',  'ganti',...          2
# 4                         ['mntep',  'dah',  'pokoknya']          2
# ...                                                  ...        ...
# 29995  ['pudate',  'update',  'main',  'pin',  'merah...          2
# 29996  ['wow',  'main',  'season',  'sampe',  'ga',  ...          2
# 29997              ['suka',  'main',  'seru',  'banget']          2
# 29998  ['kasih',  'bintang',  'download',  'ngeleg', ...          1
# 29999  ['minal',  'aidzin',  'walfa',  'idzin',  'moh...          2
#
# [30000 rows x 2 columns]

# %%
def list_tosring(text):
    return ','.join(text)
    
df_3['comment'] = df_3['comment'].apply(list_tosring)
df_3.head(10)
# Out:
#                                              comment  sentiment
# 0  'game', 'bagustapi', 'bagus', 'game', 'gimbot'...          2
# 1                                      'gem', 'bgus'          2
# 2  'akun', 'pubg', 'ku', 'kena', 'heckergimna', '...          1
# 3  'plis', 'mahal', 'mahal', 'men', 'ganti', 'mb'...          2
# 4                         'mntep', 'dah', 'pokoknya'          2
# 5  'kah', 'kedepannya', 'pubg', 'settingan', 'fps...          2
# 6                                     'game', 'seru'          2
# 7                                  'hp', 'mendukung'          2
# 8  'gamenya', 'bagus', 'tp', 'knp', 'ketemu', 'mu...          2
# 9  'up', 'date', 'mulu', 'dipasangin', 'cheat', '...          0

# %%
#hapus punctuation (tanda baca)
def remove_punctuation(text):
    return text.translate(str.maketrans("","",string.punctuation))

df_3['comment'] = df_3['comment'].apply(remove_punctuation)
df_3.head(10)
# Out:
#                                              comment  sentiment
# 0  game bagustapi bagus game gimbot karya anak ba...          2
# 1                                           gem bgus          2
# 2  akun pubg ku kena heckergimna sih mengatasi he...          1
# 3  plis mahal mahal men ganti mb men maaf ya semo...          2
# 4                                 mntep dah pokoknya          2
# 5  kah kedepannya pubg settingan fps snapdragon p...          2
# 6                                          game seru          2
# 7                                       hp mendukung          2
# 8  gamenya bagus tp knp ketemu musuh patah patah ...          2
# 9              up date mulu dipasangin cheat ghoblok          0

# %%
df_3.to_csv('reviews_clean_stopword.csv', index=False, header=True)

# %%
df_4 = pd.read_csv('/content/reviews_clean_stopword.csv')

# %%
df_4.isna().sum()
# Out:
# comment      655
# sentiment      0
# dtype: int64

# %%
df_5 =df_4.dropna(axis='rows',how='any', inplace=False)

# %%
df_5.isna().sum()
# Out:
# comment      0
# sentiment    0
# dtype: int64

# %%
df_5.to_csv('review_clean_stopwords.csv', index=False, header=True)

# %%
from google.colab import files
files.download('/content/review_clean_stopwords.csv')
